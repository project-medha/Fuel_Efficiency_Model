# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
data=pd.read_csv('FuelEfficiency.csv')
data.head()
# Out:
#               Mfr Name     Carline  Eng Displ  Cylinders Transmission  \
# 0         aston martin  Vantage V8        4.0          8     Auto(S8)
# 1  Volkswagen Group of      Chiron        8.0         16  Auto(AM-S7)
# 2       General Motors    CORVETTE        6.2          8     Auto(S8)
# 3       General Motors    CORVETTE        6.2          8     Auto(S8)
# 4       General Motors    CORVETTE        6.2          8     Auto(S8)
#
#    CityMPG  HwyMPG  CombMPG  # Gears
# 0       18      25       21        8
# 1        9      14       11        7
# 2       12      20       15        8
# 3       15      25       18        8
# 4       14      23       17        8

# %%
feature1=data['CombMPG']
feature2=data['Eng Displ']
feature3=data['Cylinders']

# %%
data={'Feature1':feature1,'Feature2':feature2, 'Feature3':feature3}
df=pd.DataFrame(data)

# %%
from sklearn.preprocessing import scale

# %%
scaled_data=scale(df)

# %%
x=scaled_data[:,0]
y=scaled_data[:,1]
z=scaled_data[:,2]

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=8)
model = model.fit(df)
# Out:
# C:\Users\91839\Anaconda\envs\GPU_enabled_env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\91839\Anaconda\envs\GPU_enabled_env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
plt.figure(figsize=(8,6))
ax=plt.axes(projection='3d')
ax.scatter3D(x,y,z,c=model.labels_.astype(float))
